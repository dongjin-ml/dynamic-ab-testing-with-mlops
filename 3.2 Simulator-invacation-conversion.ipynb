# %%
import json
import time
import requests
import pandas as pd
from spacy.lang.en import English

# %%
strTestPath = "s3://sagemaker-ap-northeast-2-419974056037/preprocessing/output/test_data/test.csv"
strAPI = "https://m07tmppemg.execute-api.ap-northeast-2.amazonaws.com/dev/dat-api"

# %%
class sim_preprocess():
    
    def __init__(self, strDataPath):
        
        self.strDataPath = strDataPath
        self.index_to_label = {0: 'NotHelpful', 1: 'Helpful'} 
        
        nlp = English()
        self.tokenizer = nlp.tokenizer
        self.index_to_label = {0: 'NotHelpful', 1: 'Helpful'} 
    
    def _labelize_df(self, df):
        return '__label__' + df['is_helpful'].apply(lambda is_helpful: self.index_to_label[is_helpful])

    def _tokenize_sent(self, sent, max_length=1000):
        return ' '.join([token.text for token in self.tokenizer(sent)])[:max_length]

    def _tokenize_df(self, df):
        return (df['review_headline'].apply(self._tokenize_sent) + ' ' + 
                df['review_body'].apply(self._tokenize_sent))
    
    def execution(self, ):
        
        pdData = pd.read_csv(self.strDataPath)
        pdInput = self._tokenize_df(pdData).to_list()
        
        return pdInput
        
class simulator():
    
    def __init__(self, ):        
        
        pass
            
    def inference(self, strDataPath, strAPI, fInterval):
            
        print ("Preparing simulator...")
        eval_prep = sim_preprocess(strDataPath)
        listInferenceInput = eval_prep.execution()
        
        pdData = pd.read_csv(strTestPath)
        pdData['review_id'] = [''.join(['r-', str(n)]) for n in range(pdData.shape[0])]
        
        for idx, (strReview, strReviewID, strProductID) in enumerate(zip(listInferenceInput, pdData.review_id, pdData.product_id)):
            #print (f"Gen-idx: {idx}, \nReviewID: {strReviewID}, \nProductID: {strProductID}, \nReview: {strReview}")
            #print (f"Interval: {fInterval}")
            #print ("===")
            
            data = {
                "mode": "inference", 
                "generator_idx": idx,
                "review_id" :strReviewID,
                "product_id": strProductID,
                "review": strReview
            }
            
            try:
                #if strProductID == 'B000EPLP3C':
                response = requests.post(strAPI, json.dumps(data))
                resp = json.loads(response.content)
                res = resp["body"]
                if idx % 100 == 0: print (idx)
                #time.sleep(fInterval) 
            except Exception as e:
                print ("ERROR", e, strReviewID)
                
                
    def invocation_conversion_simulator(self, strDataPath, strAPI, fInterval):
        
        pdData = pd.read_csv(strTestPath)
        pdData['review_id'] = [''.join(['r-', str(n)]) for n in range(pdData.shape[0])]
        pdData['user_id'] = [''.join(['u-', str(n)]) for n in range(pdData.shape[0])]

        for idx, tupleRecords in enumerate(pdData.itertuples()):
                         
            strUserID, strProductID = getattr(tupleRecords, 'user_id'), getattr(tupleRecords, 'product_id')
            bIsHelpful, strReviewID = getattr(tupleRecords, 'is_helpful'), getattr(tupleRecords, 'review_id')
                       
            data = {
                "mode": "invocation", 
                "user_id" :strUserID,
                "product_id": strProductID,
            }
            
            try:
                response = requests.post(strAPI, json.dumps(data))
                resp = json.loads(response.content)
                res = resp["body"]
                if idx % 100 == 0:
                    print (idx)
                    print (data)
                #time.sleep(fInterval) 
            except Exception as e:
                pass
                #print ("err", e)
            
            if bIsHelpful:
                
                data = {
                    "mode": "conversion", 
                    "user_id" :strUserID,
                    "product_id": strProductID,
                    "review_id": strReviewID
                }
                try:
                    response = requests.post(strAPI, json.dumps(data))
                    resp = json.loads(response.content)
                    res = resp["body"]
                    #time.sleep(fInterval) 
                    if idx % 100 == 0:
                        print (idx)
                        print (data)
                except Exception as e:
                    pass

# %%
# %%time
sim = simulator()
sim.invocation_conversion_simulator(strTestPath, strAPI, fInterval=0.00001)
# Out:
# 100
# {'mode': 'invocation', 'user_id': 'u-100', 'product_id': 'B00AF56QA8'}
# 100
# {'mode': 'conversion', 'user_id': 'u-100', 'product_id': 'B00AF56QA8', 'review_id': 'r-100'}
# 200
# {'mode': 'invocation', 'user_id': 'u-200', 'product_id': 'B000094FVE'}
# 200
# {'mode': 'conversion', 'user_id': 'u-200', 'product_id': 'B000094FVE', 'review_id': 'r-200'}
# 300
# {'mode': 'invocation', 'user_id': 'u-300', 'product_id': 'B0001A967W'}
# 400
# {'mode': 'invocation', 'user_id': 'u-400', 'product_id': 'B001IAKS3U'}
# 400
# {'mode': 'conversion', 'user_id': 'u-400', 'product_id': 'B001IAKS3U', 'review_id': 'r-400'}
# 500
# {'mode': 'invocation', 'user_id': 'u-500', 'product_id': 'B00IPKETBS'}
# 600
# {'mode': 'invocation', 'user_id': 'u-600', 'product_id': 'B00H2QUD9S'}
# 700
# {'mode': 'invocation', 'user_id': 'u-700', 'product_id': 'B002Q0ZCNC'}
# 800
# {'mode': 'invocation', 'user_id': 'u-800', 'product_id': 'B00GZC35YK'}
# 900
# {'mode': 'invocation', 'user_id': 'u-900', 'product_id': 'B006V386UG'}
# 900
# {'mode': 'conversion', 'user_id': 'u-900', 'product_id': 'B006V386UG', 'review_id': 'r-900'}
# 1000
# {'mode': 'invocation', 'user_id': 'u-1000', 'product_id': 'B002W37ESY'}
# 1100
# {'mode': 'invocation', 'user_id': 'u-1100', 'product_id': 'B004H4GMCU'}
# 1200
# {'mode': 'invocation', 'user_id': 'u-1200', 'product_id': 'B0028L7WKK'}
# 1200
# {'mode': 'conversion', 'user_id': 'u-1200', 'product_id': 'B0028L7WKK', 'review_id': 'r-1200'}
# 1300
# {'mode': 'invocation', 'user_id': 'u-1300', 'product_id': 'B002M3SMV2'}
# 1400
# {'mode': 'invocation', 'user_id': 'u-1400', 'product_id': 'B0001VGFKW'}
# 1500
# {'mode': 'invocation', 'user_id': 'u-1500', 'product_id': 'B000BONJXU'}
# 1600
# {'mode': 'invocation', 'user_id': 'u-1600', 'product_id': 'B00LAF23VI'}
# 1600
# {'mode': 'conversion', 'user_id': 'u-1600', 'product_id': 'B00LAF23VI', 'review_id': 'r-1600'}
# 1700
# {'mode': 'invocation', 'user_id': 'u-1700', 'product_id': 'B00C3ZTK9M'}
# 1800
# {'mode': 'invocation', 'user_id': 'u-1800', 'product_id': 'B0002SAE56'}
# 1800
# {'mode': 'conversion', 'user_id': 'u-1800', 'product_id': 'B0002SAE56', 'review_id': 'r-1800'}
# 1900
# {'mode': 'invocation', 'user_id': 'u-1900', 'product_id': 'B003XM9774'}
# 2000
# {'mode': 'invocation', 'user_id': 'u-2000', 'product_id': 'B00B5RP0C0'}
# 2100
# {'mode': 'invocation', 'user_id': 'u-2100', 'product_id': 'B0042F3K9W'}
# 2100
# {'mode': 'conversion', 'user_id': 'u-2100', 'product_id': 'B0042F3K9W', 'review_id': 'r-2100'}
# 2200
# {'mode': 'invocation', 'user_id': 'u-2200', 'product_id': 'B004B3GELG'}
# 2300
# {'mode': 'invocation', 'user_id': 'u-2300', 'product_id': 'B00B1UWSR6'}
# 2400
# {'mode': 'invocation', 'user_id': 'u-2400', 'product_id': 'B004QOA92A'}
# 2500
# {'mode': 'invocation', 'user_id': 'u-2500', 'product_id': 'B0077V88V8'}
# 2600
# {'mode': 'invocation', 'user_id': 'u-2600', 'product_id': 'B00LP4CRSI'}
# 2600
# {'mode': 'conversion', 'user_id': 'u-2600', 'product_id': 'B00LP4CRSI', 'review_id': 'r-2600'}
# 2700
# {'mode': 'invocation', 'user_id': 'u-2700', 'product_id': 'B00WPR82D8'}
# 2700
# {'mode': 'conversion', 'user_id': 'u-2700', 'product_id': 'B00WPR82D8', 'review_id': 'r-2700'}
# 2800
# {'mode': 'invocation', 'user_id': 'u-2800', 'product_id': 'B00W5A4LEY'}
# 2800
# {'mode': 'conversion', 'user_id': 'u-2800', 'product_id': 'B00W5A4LEY', 'review_id': 'r-2800'}
# 2900
# {'mode': 'invocation', 'user_id': 'u-2900', 'product_id': 'B0002KWSS0'}
# 3000
# {'mode': 'invocation', 'user_id': 'u-3000', 'product_id': 'B00NIHWFZU'}
# 3100
# {'mode': 'invocation', 'user_id': 'u-3100', 'product_id': 'B0000CE1VP'}
# 3200
# {'mode': 'invocation', 'user_id': 'u-3200', 'product_id': 'B001COOLAI'}
# 3200
# {'mode': 'conversion', 'user_id': 'u-3200', 'product_id': 'B001COOLAI', 'review_id': 'r-3200'}
# 3300
# {'mode': 'invocation', 'user_id': 'u-3300', 'product_id': 'B003WGRUQQ'}
# 3300
# {'mode': 'conversion', 'user_id': 'u-3300', 'product_id': 'B003WGRUQQ', 'review_id': 'r-3300'}
# 3400
# {'mode': 'invocation', 'user_id': 'u-3400', 'product_id': 'B003VWYBC2'}
# 3500
# {'mode': 'invocation', 'user_id': 'u-3500', 'product_id': 'B00WK47VEW'}
# 3500
# {'mode': 'conversion', 'user_id': 'u-3500', 'product_id': 'B00WK47VEW', 'review_id': 'r-3500'}
# 3600
# {'mode': 'invocation', 'user_id': 'u-3600', 'product_id': 'B000NFNPW2'}
# 3700
# {'mode': 'invocation', 'user_id': 'u-3700', 'product_id': 'B00BXJZ30Y'}
# 3700
# {'mode': 'conversion', 'user_id': 'u-3700', 'product_id': 'B00BXJZ30Y', 'review_id': 'r-3700'}
# 3800
# {'mode': 'invocation', 'user_id': 'u-3800', 'product_id': 'B0000DHVOP'}
# 3900
# {'mode': 'invocation', 'user_id': 'u-3900', 'product_id': 'B000069EUW'}
# 4000
# {'mode': 'invocation', 'user_id': 'u-4000', 'product_id': 'B009QX8KW2'}
# 4000
# {'mode': 'conversion', 'user_id': 'u-4000', 'product_id': 'B009QX8KW2', 'review_id': 'r-4000'}
# 4100
# {'mode': 'invocation', 'user_id': 'u-4100', 'product_id': 'B008VHHYLW'}
# 4200
# {'mode': 'invocation', 'user_id': 'u-4200', 'product_id': 'B000GAU7AM'}
# 4200
# {'mode': 'conversion', 'user_id': 'u-4200', 'product_id': 'B000GAU7AM', 'review_id': 'r-4200'}
# 4300
# {'mode': 'invocation', 'user_id': 'u-4300', 'product_id': 'B00006HYJ5'}
# 4300
# {'mode': 'conversion', 'user_id': 'u-4300', 'product_id': 'B00006HYJ5', 'review_id': 'r-4300'}
# 4400
# {'mode': 'invocation', 'user_id': 'u-4400', 'product_id': 'B000EPJL1A'}
# 4400
# {'mode': 'conversion', 'user_id': 'u-4400', 'product_id': 'B000EPJL1A', 'review_id': 'r-4400'}
# 4500
# {'mode': 'invocation', 'user_id': 'u-4500', 'product_id': 'B0019EHU8G'}
# 4500
# {'mode': 'conversion', 'user_id': 'u-4500', 'product_id': 'B0019EHU8G', 'review_id': 'r-4500'}
# 4600
# {'mode': 'invocation', 'user_id': 'u-4600', 'product_id': 'B003H04Q9G'}
# 4600
# {'mode': 'conversion', 'user_id': 'u-4600', 'product_id': 'B003H04Q9G', 'review_id': 'r-4600'}
# 4700
# {'mode': 'invocation', 'user_id': 'u-4700', 'product_id': 'B00005T3XH'}
# 4800
# {'mode': 'invocation', 'user_id': 'u-4800', 'product_id': 'B007SRNPPU'}
# 4800
# {'mode': 'conversion', 'user_id': 'u-4800', 'product_id': 'B007SRNPPU', 'review_id': 'r-4800'}
# 4900
# {'mode': 'invocation', 'user_id': 'u-4900', 'product_id': 'B004I8WHA6'}
# 4900
# {'mode': 'conversion', 'user_id': 'u-4900', 'product_id': 'B004I8WHA6', 'review_id': 'r-4900'}
# 5000
# {'mode': 'invocation', 'user_id': 'u-5000', 'product_id': 'B000BSKO84'}
# 5000
# {'mode': 'conversion', 'user_id': 'u-5000', 'product_id': 'B000BSKO84', 'review_id': 'r-5000'}
# 5100
# {'mode': 'invocation', 'user_id': 'u-5100', 'product_id': 'B00GMQ0ZKQ'}
# 5100
# {'mode': 'conversion', 'user_id': 'u-5100', 'product_id': 'B00GMQ0ZKQ', 'review_id': 'r-5100'}
# 5200
# {'mode': 'invocation', 'user_id': 'u-5200', 'product_id': 'B001AVUJXG'}
# 5200
# {'mode': 'conversion', 'user_id': 'u-5200', 'product_id': 'B001AVUJXG', 'review_id': 'r-5200'}
# 5300
# {'mode': 'invocation', 'user_id': 'u-5300', 'product_id': 'B0015L0T68'}
# 5400
# {'mode': 'invocation', 'user_id': 'u-5400', 'product_id': 'B001HBH1B2'}
# 5400
# {'mode': 'conversion', 'user_id': 'u-5400', 'product_id': 'B001HBH1B2', 'review_id': 'r-5400'}
# 5500
# {'mode': 'invocation', 'user_id': 'u-5500', 'product_id': 'B004FTMRJO'}
# 5600
# {'mode': 'invocation', 'user_id': 'u-5600', 'product_id': 'B00J6WDSF2'}
# 5600
# {'mode': 'conversion', 'user_id': 'u-5600', 'product_id': 'B00J6WDSF2', 'review_id': 'r-5600'}
# 5700
# {'mode': 'invocation', 'user_id': 'u-5700', 'product_id': 'B001G5Z82I'}
# 5700
# {'mode': 'conversion', 'user_id': 'u-5700', 'product_id': 'B001G5Z82I', 'review_id': 'r-5700'}
# 5800
# {'mode': 'invocation', 'user_id': 'u-5800', 'product_id': 'B00NJTX70E'}
# 5900
# {'mode': 'invocation', 'user_id': 'u-5900', 'product_id': 'B00020H2MW'}
# 5900
# {'mode': 'conversion', 'user_id': 'u-5900', 'product_id': 'B00020H2MW', 'review_id': 'r-5900'}
# 6000
# {'mode': 'invocation', 'user_id': 'u-6000', 'product_id': 'B000V8ASR6'}
# 6100
# {'mode': 'invocation', 'user_id': 'u-6100', 'product_id': 'B003YKG2XM'}
# 6200
# {'mode': 'invocation', 'user_id': 'u-6200', 'product_id': 'B007VQS8RI'}
# 6200
# {'mode': 'conversion', 'user_id': 'u-6200', 'product_id': 'B007VQS8RI', 'review_id': 'r-6200'}
# 6300
# {'mode': 'invocation', 'user_id': 'u-6300', 'product_id': 'B004I8WH6U'}
# 6300
# {'mode': 'conversion', 'user_id': 'u-6300', 'product_id': 'B004I8WH6U', 'review_id': 'r-6300'}
# 6400
# {'mode': 'invocation', 'user_id': 'u-6400', 'product_id': 'B00094OX32'}
# 6400
# {'mode': 'conversion', 'user_id': 'u-6400', 'product_id': 'B00094OX32', 'review_id': 'r-6400'}
# 6500
# {'mode': 'invocation', 'user_id': 'u-6500', 'product_id': 'B00004TZE5'}
# 6500
# {'mode': 'conversion', 'user_id': 'u-6500', 'product_id': 'B00004TZE5', 'review_id': 'r-6500'}
# 6600
# {'mode': 'invocation', 'user_id': 'u-6600', 'product_id': 'B000MBUSD6'}
# 6700
# {'mode': 'invocation', 'user_id': 'u-6700', 'product_id': 'B001F0H5S4'}
# 6700
# {'mode': 'conversion', 'user_id': 'u-6700', 'product_id': 'B001F0H5S4', 'review_id': 'r-6700'}
# 6800
# {'mode': 'invocation', 'user_id': 'u-6800', 'product_id': 'B0011ZNFIC'}
# 6800
# {'mode': 'conversion', 'user_id': 'u-6800', 'product_id': 'B0011ZNFIC', 'review_id': 'r-6800'}
# 6900
# {'mode': 'invocation', 'user_id': 'u-6900', 'product_id': 'B0015DMP40'}
# 6900
# {'mode': 'conversion', 'user_id': 'u-6900', 'product_id': 'B0015DMP40', 'review_id': 'r-6900'}
# 7000
# {'mode': 'invocation', 'user_id': 'u-7000', 'product_id': 'B0017T7PGK'}
# 7000
# {'mode': 'conversion', 'user_id': 'u-7000', 'product_id': 'B0017T7PGK', 'review_id': 'r-7000'}
# 7100
# {'mode': 'invocation', 'user_id': 'u-7100', 'product_id': 'B00029U126'}
# 7100
# {'mode': 'conversion', 'user_id': 'u-7100', 'product_id': 'B00029U126', 'review_id': 'r-7100'}
# 7200
# {'mode': 'invocation', 'user_id': 'u-7200', 'product_id': 'B00001OWYM'}
# 7200
# {'mode': 'conversion', 'user_id': 'u-7200', 'product_id': 'B00001OWYM', 'review_id': 'r-7200'}
# 7300
# {'mode': 'invocation', 'user_id': 'u-7300', 'product_id': 'B005VP9MO4'}
# 7300
# {'mode': 'conversion', 'user_id': 'u-7300', 'product_id': 'B005VP9MO4', 'review_id': 'r-7300'}
# 7400
# {'mode': 'invocation', 'user_id': 'u-7400', 'product_id': 'B002Y0SYLG'}
# 7400
# {'mode': 'conversion', 'user_id': 'u-7400', 'product_id': 'B002Y0SYLG', 'review_id': 'r-7400'}
# 7500
# {'mode': 'invocation', 'user_id': 'u-7500', 'product_id': 'B00HTPHK5W'}
# 7500
# {'mode': 'conversion', 'user_id': 'u-7500', 'product_id': 'B00HTPHK5W', 'review_id': 'r-7500'}
# 7600
# {'mode': 'invocation', 'user_id': 'u-7600', 'product_id': 'B00001P4AA'}
# 7700
# {'mode': 'invocation', 'user_id': 'u-7700', 'product_id': 'B0097BEDPG'}
# 7700
# {'mode': 'conversion', 'user_id': 'u-7700', 'product_id': 'B0097BEDPG', 'review_id': 'r-7700'}
# 7800
# {'mode': 'invocation', 'user_id': 'u-7800', 'product_id': 'B00065HLYC'}
# 7800
# {'mode': 'conversion', 'user_id': 'u-7800', 'product_id': 'B00065HLYC', 'review_id': 'r-7800'}
# 7900
# {'mode': 'invocation', 'user_id': 'u-7900', 'product_id': 'B005EQS9KI'}
# 8000
# {'mode': 'invocation', 'user_id': 'u-8000', 'product_id': 'B00001W0DH'}
# 8100
# {'mode': 'invocation', 'user_id': 'u-8100', 'product_id': 'B0031SQO5S'}
# 8100
# {'mode': 'conversion', 'user_id': 'u-8100', 'product_id': 'B0031SQO5S', 'review_id': 'r-8100'}
# 8200
# {'mode': 'invocation', 'user_id': 'u-8200', 'product_id': 'B000ID7QNI'}
# 8200
# {'mode': 'conversion', 'user_id': 'u-8200', 'product_id': 'B000ID7QNI', 'review_id': 'r-8200'}
# 8300
# {'mode': 'invocation', 'user_id': 'u-8300', 'product_id': 'B001DF2CQQ'}
# 8300
# {'mode': 'conversion', 'user_id': 'u-8300', 'product_id': 'B001DF2CQQ', 'review_id': 'r-8300'}
# 8400
# {'mode': 'invocation', 'user_id': 'u-8400', 'product_id': 'B00V7TWNDU'}
# 8400
# {'mode': 'conversion', 'user_id': 'u-8400', 'product_id': 'B00V7TWNDU', 'review_id': 'r-8400'}
# 8500
# {'mode': 'invocation', 'user_id': 'u-8500', 'product_id': 'B0045US6DE'}
# 8500
# {'mode': 'conversion', 'user_id': 'u-8500', 'product_id': 'B0045US6DE', 'review_id': 'r-8500'}
# 8600
# {'mode': 'invocation', 'user_id': 'u-8600', 'product_id': 'B0001YFX52'}
# 8600
# {'mode': 'conversion', 'user_id': 'u-8600', 'product_id': 'B0001YFX52', 'review_id': 'r-8600'}
# 8700
# {'mode': 'invocation', 'user_id': 'u-8700', 'product_id': 'B00005UKBM'}
# 8800
# {'mode': 'invocation', 'user_id': 'u-8800', 'product_id': 'B0010HUAIO'}
# 8900
# {'mode': 'invocation', 'user_id': 'u-8900', 'product_id': 'B00AFUE7S6'}
# 8900
# {'mode': 'conversion', 'user_id': 'u-8900', 'product_id': 'B00AFUE7S6', 'review_id': 'r-8900'}
# 9000
# {'mode': 'invocation', 'user_id': 'u-9000', 'product_id': 'B0055P0TXI'}
# 9100
# {'mode': 'invocation', 'user_id': 'u-9100', 'product_id': 'B003L1ZYYM'}
# 9200
# {'mode': 'invocation', 'user_id': 'u-9200', 'product_id': 'B005SNPTRS'}
# 9300
# {'mode': 'invocation', 'user_id': 'u-9300', 'product_id': 'B006H6OR1Y'}
# 9300
# {'mode': 'conversion', 'user_id': 'u-9300', 'product_id': 'B006H6OR1Y', 'review_id': 'r-9300'}
# 9400
# {'mode': 'invocation', 'user_id': 'u-9400', 'product_id': 'B009PPNKDA'}
# 9500
# {'mode': 'invocation', 'user_id': 'u-9500', 'product_id': 'B001LL5JDA'}
# 9500
# {'mode': 'conversion', 'user_id': 'u-9500', 'product_id': 'B001LL5JDA', 'review_id': 'r-9500'}
# 9600
# {'mode': 'invocation', 'user_id': 'u-9600', 'product_id': 'B00413XA3G'}
# 9700
# {'mode': 'invocation', 'user_id': 'u-9700', 'product_id': 'B0032RR08S'}
# 9800
# {'mode': 'invocation', 'user_id': 'u-9800', 'product_id': 'B00CACUZF6'}
# 9800
# {'mode': 'conversion', 'user_id': 'u-9800', 'product_id': 'B00CACUZF6', 'review_id': 'r-9800'}
# 9900
# {'mode': 'invocation', 'user_id': 'u-9900', 'product_id': 'B00025535U'}
# 9900
# {'mode': 'conversion', 'user_id': 'u-9900', 'product_id': 'B00025535U', 'review_id': 'r-9900'}
# 10000
# {'mode': 'invocation', 'user_id': 'u-10000', 'product_id': 'B004YI9NTS'}
# 10000
# {'mode': 'conversion', 'user_id': 'u-10000', 'product_id': 'B004YI9NTS', 'review_id': 'r-10000'}
# 10100
# {'mode': 'invocation', 'user_id': 'u-10100', 'product_id': 'B00O5XUISM'}
# 10200
# {'mode': 'invocation', 'user_id': 'u-10200', 'product_id': 'B000MCGF1O'}
# 10300
# {'mode': 'invocation', 'user_id': 'u-10300', 'product_id': 'B00AEMGGU2'}
# 10300
# {'mode': 'conversion', 'user_id': 'u-10300', 'product_id': 'B00AEMGGU2', 'review_id': 'r-10300'}
# 10400
# {'mode': 'invocation', 'user_id': 'u-10400', 'product_id': 'B001L9KMTI'}
# 10400
# {'mode': 'conversion', 'user_id': 'u-10400', 'product_id': 'B001L9KMTI', 'review_id': 'r-10400'}
# 10500
# {'mode': 'invocation', 'user_id': 'u-10500', 'product_id': 'B00N11CKMG'}
# 10600
# {'mode': 'invocation', 'user_id': 'u-10600', 'product_id': 'B00OCJRX8C'}
# 10600
# {'mode': 'conversion', 'user_id': 'u-10600', 'product_id': 'B00OCJRX8C', 'review_id': 'r-10600'}
# 10700
# {'mode': 'invocation', 'user_id': 'u-10700', 'product_id': 'B007IV8D76'}
# 10700
# {'mode': 'conversion', 'user_id': 'u-10700', 'product_id': 'B007IV8D76', 'review_id': 'r-10700'}
# 10800
# {'mode': 'invocation', 'user_id': 'u-10800', 'product_id': 'B005O81U8Y'}
# 10900
# {'mode': 'invocation', 'user_id': 'u-10900', 'product_id': 'B00000J4BF'}
# 10900
# {'mode': 'conversion', 'user_id': 'u-10900', 'product_id': 'B00000J4BF', 'review_id': 'r-10900'}
# 11000
# {'mode': 'invocation', 'user_id': 'u-11000', 'product_id': 'B00CXAE92K'}
# 11100
# {'mode': 'invocation', 'user_id': 'u-11100', 'product_id': 'B000UKUDSE'}
# 11100
# {'mode': 'conversion', 'user_id': 'u-11100', 'product_id': 'B000UKUDSE', 'review_id': 'r-11100'}
# 11200
# {'mode': 'invocation', 'user_id': 'u-11200', 'product_id': 'B0016IYKNI'}
# 11300
# {'mode': 'invocation', 'user_id': 'u-11300', 'product_id': 'B000H1UJRG'}
# 11400
# {'mode': 'invocation', 'user_id': 'u-11400', 'product_id': 'B000066E6Y'}
# 11400
# {'mode': 'conversion', 'user_id': 'u-11400', 'product_id': 'B000066E6Y', 'review_id': 'r-11400'}
# 11500
# {'mode': 'invocation', 'user_id': 'u-11500', 'product_id': 'B000I1X6PM'}
# 11500
# {'mode': 'conversion', 'user_id': 'u-11500', 'product_id': 'B000I1X6PM', 'review_id': 'r-11500'}
# 11600
# {'mode': 'invocation', 'user_id': 'u-11600', 'product_id': 'B0091CWYQ6'}
# 11700
# {'mode': 'invocation', 'user_id': 'u-11700', 'product_id': 'B0097BEFI6'}
# 11800
# {'mode': 'invocation', 'user_id': 'u-11800', 'product_id': 'B001DX9CHU'}
# 11900
# {'mode': 'invocation', 'user_id': 'u-11900', 'product_id': 'B00RFLXE0A'}
# 11900
# {'mode': 'conversion', 'user_id': 'u-11900', 'product_id': 'B00RFLXE0A', 'review_id': 'r-11900'}
# 12000
# {'mode': 'invocation', 'user_id': 'u-12000', 'product_id': 'B00008VF91'}
# 12100
# {'mode': 'invocation', 'user_id': 'u-12100', 'product_id': 'B007SP2CO2'}
# 12100
# {'mode': 'conversion', 'user_id': 'u-12100', 'product_id': 'B007SP2CO2', 'review_id': 'r-12100'}
# 12200
# {'mode': 'invocation', 'user_id': 'u-12200', 'product_id': 'B002DGTGNG'}
# 12300
# {'mode': 'invocation', 'user_id': 'u-12300', 'product_id': 'B00126V8WU'}
# 12400
# {'mode': 'invocation', 'user_id': 'u-12400', 'product_id': 'B00066FH5Q'}
# 12400
# {'mode': 'conversion', 'user_id': 'u-12400', 'product_id': 'B00066FH5Q', 'review_id': 'r-12400'}
# 12500
# {'mode': 'invocation', 'user_id': 'u-12500', 'product_id': 'B002P8M6DE'}
# 12500
# {'mode': 'conversion', 'user_id': 'u-12500', 'product_id': 'B002P8M6DE', 'review_id': 'r-12500'}
# 12600
# {'mode': 'invocation', 'user_id': 'u-12600', 'product_id': 'B001VEI290'}
# 12600
# {'mode': 'conversion', 'user_id': 'u-12600', 'product_id': 'B001VEI290', 'review_id': 'r-12600'}
# 12700
# {'mode': 'invocation', 'user_id': 'u-12700', 'product_id': 'B002ROARHS'}
# 12700
# {'mode': 'conversion', 'user_id': 'u-12700', 'product_id': 'B002ROARHS', 'review_id': 'r-12700'}
# 12800
# {'mode': 'invocation', 'user_id': 'u-12800', 'product_id': 'B0006B5RAG'}
# 12800
# {'mode': 'conversion', 'user_id': 'u-12800', 'product_id': 'B0006B5RAG', 'review_id': 'r-12800'}
# 12900
# {'mode': 'invocation', 'user_id': 'u-12900', 'product_id': 'B00S1R7F2U'}
# 12900
# {'mode': 'conversion', 'user_id': 'u-12900', 'product_id': 'B00S1R7F2U', 'review_id': 'r-12900'}
# 13000
# {'mode': 'invocation', 'user_id': 'u-13000', 'product_id': 'B000BONJXU'}
# 13100
# {'mode': 'invocation', 'user_id': 'u-13100', 'product_id': 'B00F6AVFK8'}
# 13200
# {'mode': 'invocation', 'user_id': 'u-13200', 'product_id': 'B00066UTBS'}
# 13300
# {'mode': 'invocation', 'user_id': 'u-13300', 'product_id': 'B000165ARQ'}
# 13300
# {'mode': 'conversion', 'user_id': 'u-13300', 'product_id': 'B000165ARQ', 'review_id': 'r-13300'}
# 13400
# {'mode': 'invocation', 'user_id': 'u-13400', 'product_id': 'B00A7B822A'}
# 13400
# {'mode': 'conversion', 'user_id': 'u-13400', 'product_id': 'B00A7B822A', 'review_id': 'r-13400'}
# 13500
# {'mode': 'invocation', 'user_id': 'u-13500', 'product_id': 'B00ZZO1B4A'}
# 13600
# {'mode': 'invocation', 'user_id': 'u-13600', 'product_id': 'B006BUN6ZE'}
# 13700
# {'mode': 'invocation', 'user_id': 'u-13700', 'product_id': 'B00JQ2SZ4G'}
# 13700
# {'mode': 'conversion', 'user_id': 'u-13700', 'product_id': 'B00JQ2SZ4G', 'review_id': 'r-13700'}
# 13800
# {'mode': 'invocation', 'user_id': 'u-13800', 'product_id': 'B000059ZYA'}
# 13900
# {'mode': 'invocation', 'user_id': 'u-13900', 'product_id': 'B00I482L2K'}
# 13900
# {'mode': 'conversion', 'user_id': 'u-13900', 'product_id': 'B00I482L2K', 'review_id': 'r-13900'}
# 14000
# {'mode': 'invocation', 'user_id': 'u-14000', 'product_id': 'B001ID829O'}
# 14100
# {'mode': 'invocation', 'user_id': 'u-14100', 'product_id': 'B006O711V0'}
# 14100
# {'mode': 'conversion', 'user_id': 'u-14100', 'product_id': 'B006O711V0', 'review_id': 'r-14100'}
# 14200
# {'mode': 'invocation', 'user_id': 'u-14200', 'product_id': 'B0002OZXHO'}
# CPU times: user 3min 28s, sys: 7.8 s, total: 3min 36s
# Wall time: 55min 29s
